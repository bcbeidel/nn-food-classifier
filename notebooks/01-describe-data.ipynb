# %%
# OPTIONAL: Load the "autoreload" extension so that code can change
# %load_ext autoreload

# OPTIONAL: always reload modules so that as you change code in src, it gets loaded
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os, random

import numpy as np
import matplotlib.pyplot as plt
import h5py

from src.data.make_dataset import get_test_data, get_train_data, describe_images_dimensions
from src.visualization import visualize

# %matplotlib inline

# %%
sys.path.insert(0, "/Users/bbeidel/git/nn-food-classifier")
sys.path.insert(0, "/Users/bbeidel/git/nn-food-classifier/src")

# %%
X_train, Y_train, classes = get_train_data()

# %%
describe_images_dimensions(X_train)
# Out:
# image count: 10099
# image dimensions: 32px by 32px; 3 colors

# %%
visualize.display_random_image(X_train, Y_train, classes)
# Out:
# Displaying image at index 4989 with label omelette
